# %% [markdown]
# <a href="https://colab.research.google.com/github/nagendra502/c-notes/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # arthematic opperations
#
# 1. addation
# 2. subraction
# 3. multiplication
# 4. division
# 5. floor division
# 6. exponetial
# 7. modulus

# %%
# addition
x = 100
y = 34
z = x + y
print(z)
# Out:
# 134

# %%
# subraction
x = 9356
y = 6487
z = x - y
print (z)

# %%
# modulus(%)
x = 18
y = 4
z = x % y # 18 % 6
print (z)
# Out:
# 2

# %%
# area of circle
r = 12
p = 3.14
z = p*r*r
print ("area of the crcle=",z)
# Out:
# area of the crcle= 452.304

# %%
# circumference of circle
r = 12
p = 3.14
z = 2 * p * r
print ("circumference of the crcle=",z)
# Out:
# circumference of the crcle= 75.36

# %%
# volume of cilender
p = 3.14
r = 12
h = 8
z = p*r*r*h
print ("volume of the cilender=",z)
# Out:
# volume of the cilender= 3617.2799999999997
